# %%
import pandas as pd

# %%
rural_data = pd.read_csv(r"C:\Users\annun\Documents\ruralData_1.csv")

# %%
rural_data
# Out:
#        district         taluka        village                 name_women   \
# 0       Solapur  North Solapur        Honasal  Bhagyashri Shankar Dhapate
# 1        Nanded           Loha      Borgaon A              Minakshi Patil
# 2        Nanded           Loha          Bamni   Shivkanta digambar kokate
# 3     Osmanabad          Bhoom       Ganegaon        Vijaya Vikram Jadhav
# 4     Osmanabad          Washi         Shendi       Aashra Ramdas Warakad
# ...         ...            ...            ...                         ...
# 6783    Solapur       Akkalkot  Chapalgavwadi         Rihana Ahamad Nadaf
# 6784    Solapur       Akkalkot  Chapalgavwadi      Pallavi Prakash Gowind
# 6785    Solapur       Akkalkot       Kinivadi     Bhagyashri Santosh mali
# 6786    Solapur       Akkalkot       Kinivadi   Bhourmma chidanand ulahde
# 6787    Solapur       Akkalkot       Kinivadi     Vidya prmeshvar kumbhar
#
#       age category   education  family_type  \
# ...

# %%
# regression
# predicting annunal income
